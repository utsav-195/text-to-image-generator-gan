# %% [markdown]
# <a href="https://colab.research.google.com/github/utsav-195/text-to-image-synthesizer-gan/blob/main/text_to_image_synthesizer_glove.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mounting Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Necessary imports
import glob
import pandas as pd
import urllib.request
import imageio
import os
import numpy as np

from urllib.request import urlopen

# %%
# Load Glove Function
def loadGloveModel(gloveFile):
    print("Loading Glove Model")
    f = open(gloveFile,'r',encoding="utf8")
    model = {}
    for line in f:
        try:
            splitLine = line.split()
            word = splitLine[0]
            embedding = np.array([float(val) for val in splitLine[1:]])
            model[word] = embedding
        except:
            print(word)
    print("Done.",len(model)," words loaded!")
    return model

# %%
glove_embeddings = loadGloveModel("/content/drive/Shareddrives/D4NLP Project/face_gan/embeddings/glove.6B.300d.txt")
# Out:
# Loading Glove Model
# Done. 400000  words loaded!

# %%
# Setting up the paths
train_data_path = "/content/drive/Shareddrives/D4NLP Project/flowers data/flowers"
train_images_path = "/content/drive/Shareddrives/D4NLP Project/flowers data/flowers/images/jpg"
train_captions_path = "/content/drive/Shareddrives/D4NLP Project/flowers data/flowers/text_c10"

# %% [markdown]
# The following packages will be used to implement a basic GAN system in Python/Keras.

# %%
# Imports
import tensorflow as tf
from tensorflow.keras.layers import Input, Reshape, Dropout, Dense, Concatenate 
from tensorflow.keras.layers import Flatten, BatchNormalization
from tensorflow.keras.layers import Activation, ZeroPadding2D
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import UpSampling2D, Conv2D, Conv2DTranspose
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras import initializers
from sklearn.metrics import mean_squared_error

import numpy as np
from PIL import Image
from tqdm import tqdm
import os 
import time
import matplotlib.pyplot as plt

# %%
# Formatted time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)

# %%
# Generation resolution - Must be square 
# Training data is also scaled to this.
GENERATE_RES = 2 # Generation resolution factor 
# (1=32, 2=64, 3=96, 4=128, etc.)
GENERATE_SQUARE = 32 * GENERATE_RES # rows/cols (should be square)
IMAGE_CHANNELS = 3

# Preview image 
PREVIEW_ROWS = 4
PREVIEW_COLS = 7
PREVIEW_MARGIN = 16

# Size vector to generate images from
SEED_SIZE = 100
EMBEDDING_SIZE = 300

# Configuration
DATA_PATH = train_images_path
MODEL_PATH = "/content/drive/Shareddrives/D4NLP Project/flowers data/flowers/model"
EPOCHS = 50
BATCH_SIZE = 64
BUFFER_SIZE = 4000

print(f"Will generate {GENERATE_SQUARE}px square images.")
# Out:
# Will generate 64px square images.

# %% [markdown]
# ## Data Pre-Processing

# %% [markdown]
# Next we will load and preprocess the images.  This can take awhile.  Google CoLab took around an hour to process.  Because of this we store the processed file as a binary.  This way we can simply reload the processed training data and quickly use it.  It is most efficient to only perform this operation once.  The dimensions of the image are encoded into the filename of the binary file because we need to regenerate it if these change.

# %%
# Image set has 8,188 images.  Can take over an hour 
# for initial preprocessing.
# Because of this time needed, save a Numpy preprocessed file.

training_binary_path = os.path.join("/content/drive/Shareddrives/D4NLP Project/flowers data/flowers/images/npy64",
        f'training_data_{GENERATE_SQUARE}_{GENERATE_SQUARE}_')

start = time.time()
print("Loading training images...")

training_data = []
flowers_path = sorted(os.listdir(DATA_PATH))

for filename in range(len(flowers_path)):
    path = os.path.join(DATA_PATH,flowers_path[filename])
    # print(path)
    try:
      image = Image.open(path).resize((GENERATE_SQUARE,
            GENERATE_SQUARE),Image.ANTIALIAS)
      channel = np.asarray(image).shape[2]
      if channel == 3:
        training_data.append(np.asarray(image))
    except KeyboardInterrupt:
        print("Keyboard Interrup by me...")
        break
    except:
      pass
    if len(training_data) == 100:
      training_data = np.reshape(training_data,(-1,GENERATE_SQUARE,
                GENERATE_SQUARE,IMAGE_CHANNELS))
      training_data = training_data.astype(np.float32)
      #Normalizing the input
      training_data = training_data / 127.5 - 1.

      print("Saving training image " + str(100000 + filename) + ".npy")
      np.save(training_binary_path + str(100000 + filename) + ".npy",training_data)
      elapsed = time.time()-start
      print (f'Image preprocess time: {hms_string(elapsed)}')
      training_data = []
print("Complete")
# Out:
# Loading training images...
# Saving training image 100099.npy
# Image preprocess time: 0:01:03.71
# Saving training image 100199.npy
# Image preprocess time: 0:02:09.42
# Saving training image 100299.npy
# Image preprocess time: 0:03:12.96
# Saving training image 100399.npy
# Image preprocess time: 0:04:21.10
# Saving training image 100499.npy
# Image preprocess time: 0:05:25.98
# Saving training image 100599.npy
# Image preprocess time: 0:06:31.56
# Saving training image 100699.npy
# Image preprocess time: 0:07:38.62
# Saving training image 100799.npy
# Image preprocess time: 0:08:42.61
# Saving training image 100899.npy
# Image preprocess time: 0:09:48.97
# Saving training image 100999.npy
# Image preprocess time: 0:10:52.36
# Saving training image 101099.npy
# Image preprocess time: 0:12:02.87
# Saving training image 101199.npy
# Image preprocess time: 0:13:10.82
# Saving training image 101299.npy
# Image preprocess time: 0:14:14.24
# Saving training image 101399.npy
# Image preprocess time: 0:15:17.00
# Saving training image 101499.npy
# Image preprocess time: 0:16:20.51
# Saving training image 101599.npy
# Image preprocess time: 0:17:23.34
# Saving training image 101699.npy
# Image preprocess time: 0:18:29.83
# Saving training image 101799.npy
# Image preprocess time: 0:19:39.06
# Saving training image 101899.npy
# Image preprocess time: 0:20:46.05
# Saving training image 101999.npy
# Image preprocess time: 0:21:53.11
# Saving training image 102099.npy
# Image preprocess time: 0:23:00.96
# Saving training image 102199.npy
# Image preprocess time: 0:24:06.09
# Saving training image 102299.npy
# Image preprocess time: 0:25:17.38
# Saving training image 102399.npy
# Image preprocess time: 0:26:22.68
# Saving training image 102499.npy
# Image preprocess time: 0:27:28.27
# Saving training image 102599.npy
# Image preprocess time: 0:28:34.80
# Saving training image 102699.npy
# Image preprocess time: 0:29:39.52
# Saving training image 102799.npy
# Image preprocess time: 0:30:44.82
# Saving training image 102899.npy
# Image preprocess time: 0:31:52.07
# Saving training image 102999.npy
# Image preprocess time: 0:32:58.84
# Saving training image 103099.npy
# Image preprocess time: 0:34:07.39
# Saving training image 103199.npy
# Image preprocess time: 0:35:13.27
# Saving training image 103299.npy
# Image preprocess time: 0:36:21.56
# Saving training image 103399.npy
# Image preprocess time: 0:37:25.50
# Saving training image 103499.npy
# Image preprocess time: 0:38:29.67
# Saving training image 103599.npy
# Image preprocess time: 0:39:36.31
# Saving training image 103699.npy
# Image preprocess time: 0:40:44.66
# Saving training image 103799.npy
# Image preprocess time: 0:41:53.36
# Saving training image 103899.npy
# Image preprocess time: 0:42:58.27
# Saving training image 103999.npy
# Image preprocess time: 0:44:05.34
# Saving training image 104099.npy
# Image preprocess time: 0:45:10.72
# Saving training image 104199.npy
# Image preprocess time: 0:46:21.73
# Saving training image 104299.npy
# Image preprocess time: 0:47:30.55
# Saving training image 104399.npy
# Image preprocess time: 0:48:39.05
# Saving training image 104499.npy
# Image preprocess time: 0:49:47.89
# Saving training image 104599.npy
# Image preprocess time: 0:50:59.63
# Saving training image 104699.npy
# Image preprocess time: 0:52:06.95
# Saving training image 104799.npy
# Image preprocess time: 0:53:17.63
# Saving training image 104899.npy
# Image preprocess time: 0:54:22.99
# Saving training image 104999.npy
# Image preprocess time: 0:55:25.11
# Saving training image 105099.npy
# Image preprocess time: 0:56:34.27
# Saving training image 105199.npy
# Image preprocess time: 0:57:41.20
# Saving training image 105299.npy
# Image preprocess time: 0:58:51.03
# Saving training image 105399.npy
# Image preprocess time: 0:59:51.42
# Saving training image 105499.npy
# Image preprocess time: 1:01:01.85
# Saving training image 105599.npy
# Image preprocess time: 1:02:08.55
# Saving training image 105699.npy
# Image preprocess time: 1:03:25.15
# Saving training image 105799.npy
# Image preprocess time: 1:04:30.47
# Saving training image 105899.npy
# Image preprocess time: 1:05:36.18
# Saving training image 105999.npy
# Image preprocess time: 1:06:37.67
# Saving training image 106099.npy
# Image preprocess time: 1:07:43.30
# Saving training image 106199.npy
# Image preprocess time: 1:08:52.81
# Saving training image 106299.npy
# Image preprocess time: 1:10:00.15
# Saving training image 106399.npy
# Image preprocess time: 1:11:09.25
# Saving training image 106499.npy
# Image preprocess time: 1:12:14.52
# Saving training image 106599.npy
# Image preprocess time: 1:13:20.48
# Saving training image 106699.npy
# Image preprocess time: 1:14:26.46
# Saving training image 106799.npy
# Image preprocess time: 1:15:37.32
# Saving training image 106899.npy
# Image preprocess time: 1:16:47.80
# Saving training image 106999.npy
# Image preprocess time: 1:17:59.89
# Saving training image 107099.npy
# Image preprocess time: 1:19:06.42
# Saving training image 107199.npy
# Image preprocess time: 1:19:56.07
# Saving training image 107299.npy
# Image preprocess time: 1:20:27.13
# Saving training image 107399.npy
# Image preprocess time: 1:21:19.22
# Saving training image 107499.npy
# Image preprocess time: 1:22:25.92
# Saving training image 107599.npy
# Image preprocess time: 1:23:32.91
# Saving training image 107699.npy
# Image preprocess time: 1:24:44.70
# Saving training image 107799.npy
# Image preprocess time: 1:25:57.17
# Saving training image 107899.npy
# Image preprocess time: 1:27:05.11
# Saving training image 107999.npy
# Image preprocess time: 1:28:14.67
# Saving training image 108099.npy
# Image preprocess time: 1:29:28.48
# Complete

# %% [markdown]
# Next we will load and preprocess the captions. This can take awhile. Google CoLab took around an hour to process. Because of this we store the processed file as a binary. This way we can simply reload the processed data and quickly use it. It is most efficient to only perform this operation once.

# %%
text_path = "/content/drive/Shareddrives/D4NLP Project/flowers data/flowers/text_c10/captions"
text_files = sorted(os.listdir(text_path))
captions = []
caption_embeddings = np.zeros((len(text_files),300),dtype=np.float32)
for filename in range(len(text_files)):
    path = os.path.join(text_path,text_files[filename])
    # print(path)
    f = open(path,'r')
    data = f.read()
    data = data.split("\n")
    f.close()
    for d in range(1):
      x = data[d].lower()
      x = x.replace(" ","")
      captions.append(x)
      count = 0
      for t in x:
        try:
          caption_embeddings[filename] += glove_embeddings[t]
          count += 1
        except:
          print(t)
          pass
      caption_embeddings[filename] /= count
    if filename %100 == 0:
      print("-------------Files completed:",filename)

# %%
# saving the caption embeddings numpy
embedding_binary_path = os.path.join('/content/drive/Shareddrives/D4NLP Project/flowers data/flowers/images/embedding_npy',
        f'embedding_data_character.npy')
# print("Saving captions embeddings binary...")
# np.save(embedding_binary_path,caption_embeddings)

# %%
# saving the caption embeddings numpy
embedding_binary_path = os.path.join('/content/drive/Shareddrives/D4NLP Project/flowers data/flowers/images/embedding_npy',
        f'embedding_data.npy')
print("Saving captions embeddings binary...")
np.save(embedding_binary_path,caption_embeddings)

# %%
# Creating a dataframe to store the captions
df_captions = pd.DataFrame([])
df_captions['captions'] = captions[:len(final_images)]

# %%
df_captions.head()
# Out:
#                                             captions
# 0  prominent purple stigma , petals are white inc...
# 1  this flower has bright purple ,  spiky petals ...
# 2  this flower has a row of white petals with the...
# 3  this flower is white and blue in color ,  with...
# 4  this flower has petals that are green with str...

# %%
captions[:10]
# Out:
# ['prominent purple stigma , petals are white inc olor',
#  'this flower has bright purple ,  spiky petals ,  and greenish sepals below them . ',
#  'this flower has a row of white petals with the multi - colored stamens and a pistil at the centre',
#  'this flower is white and blue in color ,  with petals that are oval shaped . ',
#  'this flower has petals that are green with stringy purple stamen',
#  'this flower is blue and green in color ,  with petals that are oval shaped . ',
#  'the petals of the flower are bright blue with white lines ,  and the stamen is bright green with black dots . ',
#  'the flower has stamen and the petals are green in color . ',
#  'this flower has green petals and purple and green stamen . ',
#  'the flower shown has green pollen tubes with green sepal and blue petals']

# %%
df_captions.to_csv("/content/drive/Shareddrives/D4NLP Project/flowers data/flowers/text_c10/captions.csv",index=None)

# %% [markdown]
# ## Loading and combining numpys

# %%
embedding_binary_path = os.path.join('/content/drive/Shareddrives/D4NLP Project/flowers data/flowers/images/embedding_npy',
        f'embedding_data.npy')

# %%
caption_embeddings = np.load(embedding_binary_path)

# %%
caption_embeddings.shape
# Out:
# (8189, 300)

# %%
caption_embeddings = caption_embeddings[::5]

# %%
caption_embeddings.shape
# Out:
# (8188, 300)

# %%
image_binary_path = "/content/drive/Shareddrives/D4NLP Project/flowers data/flowers/images/npy64/"
images = os.listdir(image_binary_path)

# %%
images[-1]
# Out:
# 'training_data_64_64_108099.npy'

# %%
# Creating a list of all the preprocessed images
final_images = np.load(image_binary_path + images[0])
for i in images[1:]:
  print(i)
  try:
    final_images = np.concatenate([final_images,np.load(image_binary_path + i)],axis = 0)
  except:
    pass
# Out:
# training_data_64_64_100199.npy
# training_data_64_64_100299.npy
# training_data_64_64_100399.npy
# training_data_64_64_100499.npy
# training_data_64_64_100599.npy
# training_data_64_64_100699.npy
# training_data_64_64_100799.npy
# training_data_64_64_100899.npy
# training_data_64_64_100999.npy
# training_data_64_64_101099.npy
# training_data_64_64_101199.npy
# training_data_64_64_101299.npy
# training_data_64_64_101399.npy
# training_data_64_64_101499.npy
# training_data_64_64_101599.npy
# training_data_64_64_101699.npy
# training_data_64_64_101799.npy
# training_data_64_64_101899.npy
# training_data_64_64_101999.npy
# training_data_64_64_102099.npy
# training_data_64_64_102199.npy
# training_data_64_64_102299.npy
# training_data_64_64_102399.npy
# training_data_64_64_102499.npy
# training_data_64_64_102599.npy
# training_data_64_64_102699.npy
# training_data_64_64_102799.npy
# training_data_64_64_102899.npy
# training_data_64_64_102999.npy
# training_data_64_64_103099.npy
# training_data_64_64_103199.npy
# training_data_64_64_103299.npy
# training_data_64_64_103399.npy
# training_data_64_64_103499.npy
# training_data_64_64_103599.npy
# training_data_64_64_103699.npy
# training_data_64_64_103799.npy
# training_data_64_64_103899.npy
# training_data_64_64_103999.npy
# training_data_64_64_104099.npy
# training_data_64_64_104199.npy
# training_data_64_64_104299.npy
# training_data_64_64_104399.npy
# training_data_64_64_104499.npy
# training_data_64_64_104599.npy
# training_data_64_64_104699.npy
# training_data_64_64_104799.npy
# training_data_64_64_104899.npy
# training_data_64_64_104999.npy
# training_data_64_64_105099.npy
# training_data_64_64_105199.npy
# training_data_64_64_105299.npy
# training_data_64_64_105399.npy
# training_data_64_64_105499.npy
# training_data_64_64_105599.npy
# training_data_64_64_105699.npy
# training_data_64_64_105799.npy
# training_data_64_64_105899.npy
# training_data_64_64_105999.npy
# training_data_64_64_106099.npy
# training_data_64_64_106199.npy
# training_data_64_64_106299.npy
# training_data_64_64_106399.npy
# training_data_64_64_106499.npy
# training_data_64_64_106599.npy
# training_data_64_64_106699.npy
# training_data_64_64_106799.npy
# training_data_64_64_106899.npy
# training_data_64_64_106999.npy
# training_data_64_64_107099.npy
# training_data_64_64_107199.npy
# training_data_64_64_107299.npy
# training_data_64_64_107399.npy
# training_data_64_64_107499.npy
# training_data_64_64_107599.npy
# training_data_64_64_107699.npy
# training_data_64_64_107799.npy
# training_data_64_64_107899.npy
# training_data_64_64_107999.npy
# training_data_64_64_108099.npy

# %%
final_images.shape
# Out:
# (8100, 64, 64, 3)

# %%
df_captions = pd.read_csv("/content/drive/Shareddrives/D4NLP Project/flowers data/flowers/text_c10/captions.csv")

# %%
df_captions.head()
# Out:
#                                             captions
# 0  prominent purple stigma , petals are white inc...
# 1  this flower has bright purple ,  spiky petals ...
# 2  this flower has a row of white petals with the...
# 3  this flower is white and blue in color ,  with...
# 4  this flower has petals that are green with str...

# %%
captions = list(df_captions.captions[::5])

# %%
len(captions)
# Out:
# 8100

# %% [markdown]
# Saved images separately for testing

# %%
save_images_captions = captions[:28].copy()
save_images_embeddings = np.copy(caption_embeddings[:28])
save_images_npy = np.copy(final_images[:28])

# %%
caption_embeddings = caption_embeddings[:final_images.shape[0]]

# %%
caption_embeddings.shape
# Out:
# (8100, 300)

# %% [markdown]
# Shuffling the data

# %%
p = np.random.permutation(len(final_images))

# %%
final_images_shuffled = final_images[p]
final_embeddings_shuffled = caption_embeddings[p]

# %%
final_images_shuffled.shape
# Out:
# (8100, 64, 64, 3)

# %%
final_embeddings_shuffled.shape
# Out:
# (8100, 300)

# %%
# Batch and shuffle the data
# train_dataset = tf.data.Dataset.from_tensor_slices(training_data) \
#     .shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
train_dataset = tf.data.Dataset.from_tensor_slices({'images': final_images,
                                                    'embeddings': caption_embeddings}).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %% [markdown]
# ## Data Modeling

# %% [markdown]
# Defining the Generator and Discriminator

# %%
def build_generator_func(seed_size,embedding_size, channels):
  input_seed = Input(shape=seed_size)
  input_embed = Input(shape = embedding_size)
  d0 = Dense(128)(input_embed)
  leaky0 = LeakyReLU(alpha=0.2)(d0)

  merge = Concatenate()([input_seed, leaky0])

  d1 = Dense(4*4*256,activation="relu")(merge)
  reshape = Reshape((4,4,256))(d1)

  upSamp1 = UpSampling2D()(reshape)
  conv2d1 = Conv2DTranspose(256,kernel_size=5,padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.02))(upSamp1)
  batchNorm1 = BatchNormalization(momentum=0.8)(conv2d1)
  leaky1 = LeakyReLU(alpha=0.2)(batchNorm1)

  upSamp2 = UpSampling2D()(leaky1)
  conv2d2 = Conv2DTranspose(256,kernel_size=5,padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.02))(upSamp2)
  batchNorm2 = BatchNormalization(momentum=0.8)(conv2d2)
  leaky2 = LeakyReLU(alpha=0.2)(batchNorm2)

  upSamp3 = UpSampling2D()(leaky2)
  conv2d3 = Conv2DTranspose(128,kernel_size=4,padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.02))(upSamp3)
  batchNorm3 = BatchNormalization(momentum=0.8)(conv2d3)
  leaky3 = LeakyReLU(alpha=0.2)(batchNorm3)

  upSamp4 = UpSampling2D(size=(GENERATE_RES,GENERATE_RES))(leaky3)
  conv2d4 = Conv2DTranspose(128,kernel_size=4,padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.02))(upSamp4)
  batchNorm4 = BatchNormalization(momentum=0.8)(conv2d4)
  leaky4 = LeakyReLU(alpha=0.2)(batchNorm4)

  outputConv = Conv2DTranspose(channels,kernel_size=3,padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.02))(leaky4)
  outputActi = Activation("tanh")(outputConv)

  model = Model(inputs=[input_seed,input_embed], outputs=outputActi)
  return model

def build_discriminator_func(image_shape, embedding_size):
  input_shape = Input(shape=image_shape)
  input_embed = Input(shape=embedding_size)

  conv2d1 = Conv2D(32,kernel_size=4,strides=2,input_shape=image_shape,padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.02))(input_shape)
  leaky1 = LeakyReLU(alpha=0.2)(conv2d1)

  drop2 = Dropout(0.25)(leaky1)
  conv2d2 = Conv2D(64, kernel_size=4, strides=2, padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.02))(drop2)
  # zero2 = ZeroPadding2D(padding=((0,1),(0,1)))(conv2d2)
  batchNorm2 = BatchNormalization(momentum=0.8)(conv2d2)
  leaky2 = LeakyReLU(alpha=0.2)(batchNorm2)

  drop3 = Dropout(0.25)(leaky2)
  conv2d3 = Conv2D(128, kernel_size=4, strides=2, padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.02))(drop3)
  batchNorm3 = BatchNormalization(momentum=0.8)(conv2d3)
  leaky3 = LeakyReLU(alpha=0.2)(batchNorm3)

  drop4 = Dropout(0.25)(leaky3)
  conv2d4 = Conv2D(256, kernel_size=4, strides=2, padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.02))(drop4)
  batchNorm4 = BatchNormalization(momentum=0.8)(conv2d4)
  leaky4 = LeakyReLU(alpha=0.2)(batchNorm4)

  dense_embed = Dense(128,kernel_initializer=initializers.RandomNormal(stddev=0.02))(input_embed)
  leaky_embed = LeakyReLU(alpha=0.2)(dense_embed)
  reshape_embed = Reshape((4,4,8))(leaky_embed)
  merge_embed = Concatenate()([leaky4, reshape_embed])

  drop5 = Dropout(0.25)(merge_embed)
  conv2d5 = Conv2D(512, kernel_size=4,kernel_initializer=initializers.RandomNormal(stddev=0.02))(drop5)
  batchNorm5 = BatchNormalization(momentum=0.8)(conv2d5)
  leaky5 = LeakyReLU(alpha=0.2)(batchNorm5)

  drop6 = Dropout(0.25)(leaky5)
  flatten = Flatten()(drop6)
  output = Dense(1,activation="sigmoid")(flatten)

  model = Model(inputs=[input_shape,input_embed], outputs=output)
  return model

# %% [markdown]
# Function to save image samples generated

# %%
def save_images(cnt,noise,embeds):
  image_array = np.full(( 
      PREVIEW_MARGIN + (PREVIEW_ROWS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 
      PREVIEW_MARGIN + (PREVIEW_COLS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 3), 
      255, dtype=np.uint8)

  generated_images = generator.predict((noise,embeds))

  generated_images = 0.5 * generated_images + 0.5

  image_count = 0
  for row in range(PREVIEW_ROWS):
      for col in range(PREVIEW_COLS):
        r = row * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        c = col * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        image_array[r:r+GENERATE_SQUARE,c:c+GENERATE_SQUARE] \
            = generated_images[image_count] * 255
        image_count += 1

          
  output_path = "/content/drive/Shareddrives/D4NLP Project/flowers data/flowers/output_64_character_extended"
  if not os.path.exists(output_path):
    os.makedirs(output_path)

  filename = os.path.join(output_path,f"train-{cnt}.png")
  im = Image.fromarray(image_array)
  im.save(filename)

# %%
# Initlializing a generator
generator = build_generator_func(SEED_SIZE,EMBEDDING_SIZE, IMAGE_CHANNELS)
generator.load_weights("/content/drive/Shareddrives/D4NLP Project/flowers data/flowers/model/text_to_image_generator_cub_character.h5")

# %%
# Sample output from the Generator
noise = tf.random.normal([1, 100])
generated_image = generator((noise,caption_embeddings[5].reshape(1,300)), training=False)

plt.imshow(generated_image[0, :, :, 0])

# %%
# Initlializing a discriminator
image_shape = (GENERATE_SQUARE,GENERATE_SQUARE,IMAGE_CHANNELS)

discriminator = build_discriminator_func(image_shape,EMBEDDING_SIZE)
discriminator.load_weights((os.path.join(MODEL_PATH,"text_to_image_disc_cub_character.h5")))

# %%
decision = discriminator((generated_image,caption_embeddings[5].reshape(1,300)))
print(decision)
# Out:
# tf.Tensor([[0.2522805]], shape=(1, 1), dtype=float32)

# %%
# This method returns a helper function to compute cross entropy loss
cross_entropy = tf.keras.losses.BinaryCrossentropy()

def discriminator_loss(real_image_real_text, fake_image_real_text, real_image_fake_text):
    real_loss = cross_entropy(tf.random.uniform(real_image_real_text.shape,0.8,1.0), real_image_real_text)
    fake_loss = (cross_entropy(tf.random.uniform(fake_image_real_text.shape,0.0,0.2), fake_image_real_text) + 
                 cross_entropy(tf.random.uniform(real_image_fake_text.shape,0.0,0.2), real_image_fake_text))/2

    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %% [markdown]
# Both the generator and discriminator use Adam and the same learning rate and momentum.  This does not need to be the case.  If you use a **GENERATE_RES** greater than 3 you may need to tune these learning rates, as well as other training and hyperparameters.

# %%
# lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
#     initial_learning_rate=2e-4,
#     decay_steps=100,
#     decay_rate=0.5)
generator_optimizer = tf.keras.optimizers.Adam(learning_rate=2.0e-4,beta_1 = 0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(learning_rate=2.0e-4,beta_1 = 0.5)

# %% [markdown]
# ## Training

# %%
# Notice the use of `tf.function`
# This annotation causes the function to be "compiled".
@tf.function
def train_step(images,captions,fake_captions):
  seed = tf.random.normal([BATCH_SIZE, SEED_SIZE],dtype=tf.float32)

  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    generated_images = generator((seed,captions), training=True)
    real_image_real_text = discriminator((images,captions), training=True)
    real_image_fake_text = discriminator((images,fake_captions), training=True)
    fake_image_real_text = discriminator((generated_images,captions), training=True)

    gen_loss = generator_loss(fake_image_real_text)
    disc_loss = discriminator_loss(real_image_real_text, fake_image_real_text, real_image_fake_text)
    # print(gen_loss)
    # print(disc_loss)

    gradients_of_generator = gen_tape.gradient(\
        gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(\
        disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(
        gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(
        gradients_of_discriminator, 
        discriminator.trainable_variables))
  return gen_loss,disc_loss

# %%
# Function that executes trianing process
def train(train_dataset, epochs):
  fixed_seed = np.random.normal(0, 1, (PREVIEW_ROWS * PREVIEW_COLS, 
                                       SEED_SIZE))
  fixed_embed = save_images_embeddings

  start = time.time()

  for epoch in range(epochs):
    print("epoch start...")
    epoch_start = time.time()

    gen_loss_list = []
    disc_loss_list = []

    for batch in train_dataset[:-1]:
      # train_batch = training_data[BATCH_SIZE*image_batch : BATCH_SIZE*image_batch + BATCH_SIZE]
      # caption_batch = captions[BATCH_SIZE*image_batch : BATCH_SIZE*image_batch + BATCH_SIZE]
      train_batch = batch['images']
      caption_batch = batch['embeddings']
      
      fake_caption_batch = np.copy(caption_batch)
      np.random.shuffle(fake_caption_batch)
      
      t = train_step(train_batch,caption_batch,fake_caption_batch)
      # print(t)
      gen_loss_list.append(t[0])
      disc_loss_list.append(t[1])
      # if image_batch%50 == 0:
      #   print(image_batch)
      # print("here")
    print("now")
    g_loss = sum(gen_loss_list) / len(gen_loss_list)
    d_loss = sum(disc_loss_list) / len(disc_loss_list)

    epoch_elapsed = time.time()-epoch_start
    print(f'Epoch {epoch+1}, gen loss={g_loss},disc loss={d_loss}, {hms_string(epoch_elapsed)}')
    save_images(epoch,fixed_seed,fixed_embed)
    
    generator.save(os.path.join(MODEL_PATH,"text_to_image_generator_cub_character.h5"))
    discriminator.save(os.path.join(MODEL_PATH,"text_to_image_disc_cub_character.h5"))
    print("model saved")

  elapsed = time.time()-start
  print ('Training time:', hms_string(elapsed))

# %%
train(list(train_dataset.as_numpy_iterator()), 500)
# Out:
# epoch start...
# now
# Epoch 1, gen loss=0.7686348557472229,disc loss=1.5495121479034424, 0:00:16.03
# model saved
# epoch start...
# now
# Epoch 2, gen loss=0.7586959600448608,disc loss=1.4737610816955566, 0:00:13.88
# model saved
# epoch start...
# now
# Epoch 3, gen loss=0.7599285840988159,disc loss=1.4424796104431152, 0:00:13.88
# model saved
# epoch start...
# now
# Epoch 4, gen loss=0.7321832776069641,disc loss=1.4321304559707642, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 5, gen loss=0.7370102405548096,disc loss=1.4232256412506104, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 6, gen loss=0.7280808091163635,disc loss=1.4163377285003662, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 7, gen loss=0.7229128479957581,disc loss=1.4120633602142334, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 8, gen loss=0.726793110370636,disc loss=1.4074561595916748, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 9, gen loss=0.719771683216095,disc loss=1.4027323722839355, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 10, gen loss=0.7308263778686523,disc loss=1.3960766792297363, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 11, gen loss=0.7322098612785339,disc loss=1.3940274715423584, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 12, gen loss=0.738957405090332,disc loss=1.394586443901062, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 13, gen loss=0.7285746932029724,disc loss=1.3948612213134766, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 14, gen loss=0.7227734923362732,disc loss=1.3913838863372803, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 15, gen loss=0.7259846329689026,disc loss=1.3856890201568604, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 16, gen loss=0.7517513036727905,disc loss=1.3781495094299316, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 17, gen loss=0.7682901620864868,disc loss=1.3687852621078491, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 18, gen loss=0.8093228936195374,disc loss=1.353394865989685, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 19, gen loss=0.8467414379119873,disc loss=1.346270203590393, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 20, gen loss=0.8456972241401672,disc loss=1.3435696363449097, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 21, gen loss=0.8820129036903381,disc loss=1.328046441078186, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 22, gen loss=0.8172005414962769,disc loss=1.3606241941452026, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 23, gen loss=0.8409094214439392,disc loss=1.3441368341445923, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 24, gen loss=0.8975818157196045,disc loss=1.320762276649475, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 25, gen loss=0.8324954509735107,disc loss=1.354278326034546, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 26, gen loss=0.8208280801773071,disc loss=1.3491758108139038, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 27, gen loss=0.7434625625610352,disc loss=1.3835302591323853, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 28, gen loss=0.7484328150749207,disc loss=1.3708876371383667, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 29, gen loss=0.7793771624565125,disc loss=1.3588989973068237, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 30, gen loss=0.7891846895217896,disc loss=1.3615937232971191, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 31, gen loss=0.8162000179290771,disc loss=1.350082516670227, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 32, gen loss=0.8046369552612305,disc loss=1.3540518283843994, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 33, gen loss=0.7892026901245117,disc loss=1.355515956878662, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 34, gen loss=0.8286486268043518,disc loss=1.3390389680862427, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 35, gen loss=0.8060910105705261,disc loss=1.3497496843338013, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 36, gen loss=0.799767255783081,disc loss=1.3497916460037231, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 37, gen loss=0.8128068447113037,disc loss=1.3467872142791748, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 38, gen loss=0.7978296279907227,disc loss=1.354109525680542, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 39, gen loss=0.7487815618515015,disc loss=1.3743202686309814, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 40, gen loss=0.7343626022338867,disc loss=1.3717752695083618, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 41, gen loss=0.7263383865356445,disc loss=1.3743680715560913, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 42, gen loss=0.7313573360443115,disc loss=1.3680716753005981, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 43, gen loss=0.7253585457801819,disc loss=1.373397946357727, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 44, gen loss=0.7290821671485901,disc loss=1.366402268409729, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 45, gen loss=0.7670776844024658,disc loss=1.3513164520263672, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 46, gen loss=0.759506106376648,disc loss=1.353654146194458, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 47, gen loss=0.7542323470115662,disc loss=1.3564975261688232, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 48, gen loss=0.7540428638458252,disc loss=1.351373553276062, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 49, gen loss=0.7570541501045227,disc loss=1.3552180528640747, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 50, gen loss=0.8027423620223999,disc loss=1.337469220161438, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 51, gen loss=0.781998872756958,disc loss=1.3458446264266968, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 52, gen loss=0.7962406277656555,disc loss=1.339636206626892, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 53, gen loss=0.8129223585128784,disc loss=1.333735466003418, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 54, gen loss=0.8159731030464172,disc loss=1.3359180688858032, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 55, gen loss=0.8241830468177795,disc loss=1.3251296281814575, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 56, gen loss=0.8146219253540039,disc loss=1.3342067003250122, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 57, gen loss=0.8323482275009155,disc loss=1.3256070613861084, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 58, gen loss=0.8112983703613281,disc loss=1.3325990438461304, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 59, gen loss=0.7959238886833191,disc loss=1.3454546928405762, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 60, gen loss=0.7902194857597351,disc loss=1.343325138092041, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 61, gen loss=0.8207894563674927,disc loss=1.3297476768493652, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 62, gen loss=0.8082678318023682,disc loss=1.3332958221435547, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 63, gen loss=0.7998436689376831,disc loss=1.3355185985565186, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 64, gen loss=0.7996323704719543,disc loss=1.3410509824752808, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 65, gen loss=0.8173432946205139,disc loss=1.3357915878295898, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 66, gen loss=0.7856248021125793,disc loss=1.3471542596817017, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 67, gen loss=0.774070680141449,disc loss=1.342751383781433, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 68, gen loss=0.803447425365448,disc loss=1.3359330892562866, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 69, gen loss=0.7817940711975098,disc loss=1.3398395776748657, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 70, gen loss=0.7922214865684509,disc loss=1.3400770425796509, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 71, gen loss=0.826335608959198,disc loss=1.3242576122283936, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 72, gen loss=0.859481155872345,disc loss=1.314734697341919, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 73, gen loss=0.8833779096603394,disc loss=1.311851978302002, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 74, gen loss=0.8245667815208435,disc loss=1.333709955215454, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 75, gen loss=0.8063550591468811,disc loss=1.3354687690734863, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 76, gen loss=0.8431293368339539,disc loss=1.3149389028549194, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 77, gen loss=0.8262848854064941,disc loss=1.3256590366363525, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 78, gen loss=0.8365756273269653,disc loss=1.3165912628173828, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 79, gen loss=0.8738360404968262,disc loss=1.309719204902649, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 80, gen loss=0.8796119093894958,disc loss=1.3119254112243652, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 81, gen loss=0.865702748298645,disc loss=1.3127821683883667, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 82, gen loss=0.8409505486488342,disc loss=1.328861117362976, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 83, gen loss=0.8629409074783325,disc loss=1.316052794456482, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 84, gen loss=0.8477832078933716,disc loss=1.3210331201553345, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 85, gen loss=0.8576914668083191,disc loss=1.311285376548767, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 86, gen loss=0.8631856441497803,disc loss=1.3120970726013184, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 87, gen loss=0.8460227251052856,disc loss=1.314186453819275, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 88, gen loss=0.865961492061615,disc loss=1.3088583946228027, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 89, gen loss=0.8791435956954956,disc loss=1.3132458925247192, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 90, gen loss=0.8492963910102844,disc loss=1.3118910789489746, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 91, gen loss=0.8260812163352966,disc loss=1.3260407447814941, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 92, gen loss=0.8495608568191528,disc loss=1.3115261793136597, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 93, gen loss=0.8590570092201233,disc loss=1.3129903078079224, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 94, gen loss=0.8716009259223938,disc loss=1.3055039644241333, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 95, gen loss=0.866560697555542,disc loss=1.3002773523330688, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 96, gen loss=0.906151294708252,disc loss=1.2962992191314697, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 97, gen loss=0.9870898723602295,disc loss=1.2688814401626587, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 98, gen loss=1.006248950958252,disc loss=1.2713513374328613, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 99, gen loss=0.9942307472229004,disc loss=1.263585090637207, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 100, gen loss=0.9857509732246399,disc loss=1.261342167854309, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 101, gen loss=0.9685615301132202,disc loss=1.2733255624771118, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 102, gen loss=0.9397596120834351,disc loss=1.2790180444717407, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 103, gen loss=0.9269494414329529,disc loss=1.2830078601837158, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 104, gen loss=0.9412521719932556,disc loss=1.2743067741394043, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 105, gen loss=0.9604415893554688,disc loss=1.2709022760391235, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 106, gen loss=0.9553481936454773,disc loss=1.2741072177886963, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 107, gen loss=0.9348879456520081,disc loss=1.274978756904602, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 108, gen loss=0.9104464650154114,disc loss=1.2941257953643799, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 109, gen loss=0.8951358199119568,disc loss=1.2855545282363892, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 110, gen loss=0.9563668966293335,disc loss=1.2647302150726318, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 111, gen loss=0.9898335337638855,disc loss=1.255224347114563, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 112, gen loss=1.0040504932403564,disc loss=1.249265432357788, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 113, gen loss=0.9808609485626221,disc loss=1.259832739830017, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 114, gen loss=1.033189296722412,disc loss=1.244550347328186, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 115, gen loss=1.002852201461792,disc loss=1.2463849782943726, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 116, gen loss=1.0154350996017456,disc loss=1.2458140850067139, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 117, gen loss=1.0271120071411133,disc loss=1.2415217161178589, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 118, gen loss=1.0959653854370117,disc loss=1.2192566394805908, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 119, gen loss=1.0291820764541626,disc loss=1.2409192323684692, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 120, gen loss=0.9907305836677551,disc loss=1.2512558698654175, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 121, gen loss=1.0204765796661377,disc loss=1.2364284992218018, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 122, gen loss=1.0485130548477173,disc loss=1.2385022640228271, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 123, gen loss=0.9661232829093933,disc loss=1.2590556144714355, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 124, gen loss=0.96770840883255,disc loss=1.262039303779602, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 125, gen loss=0.9769761562347412,disc loss=1.2527331113815308, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 126, gen loss=0.9808560609817505,disc loss=1.2496592998504639, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 127, gen loss=1.0462671518325806,disc loss=1.2276297807693481, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 128, gen loss=1.047224760055542,disc loss=1.2374086380004883, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 129, gen loss=1.0398294925689697,disc loss=1.2277053594589233, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 130, gen loss=0.9748565554618835,disc loss=1.2534921169281006, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 131, gen loss=1.042755365371704,disc loss=1.2267284393310547, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 132, gen loss=1.0252381563186646,disc loss=1.234276533126831, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 133, gen loss=1.0405364036560059,disc loss=1.2269631624221802, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 134, gen loss=1.0528103113174438,disc loss=1.2240307331085205, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 135, gen loss=1.0915844440460205,disc loss=1.2084580659866333, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 136, gen loss=1.056727409362793,disc loss=1.2270033359527588, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 137, gen loss=1.0302332639694214,disc loss=1.2342264652252197, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 138, gen loss=1.0307011604309082,disc loss=1.2358182668685913, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 139, gen loss=1.0113394260406494,disc loss=1.2363277673721313, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 140, gen loss=1.0300087928771973,disc loss=1.2240899801254272, 0:00:13.93
# model saved
# epoch start...
# now
# Epoch 141, gen loss=1.0159274339675903,disc loss=1.2282001972198486, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 142, gen loss=1.0800658464431763,disc loss=1.2215213775634766, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 143, gen loss=1.1803240776062012,disc loss=1.1785142421722412, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 144, gen loss=1.210593581199646,disc loss=1.1822806596755981, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 145, gen loss=1.138336181640625,disc loss=1.1985321044921875, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 146, gen loss=1.1063669919967651,disc loss=1.210178256034851, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 147, gen loss=1.074734091758728,disc loss=1.210873007774353, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 148, gen loss=1.1019740104675293,disc loss=1.2029615640640259, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 149, gen loss=1.09027099609375,disc loss=1.2052775621414185, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 150, gen loss=1.071121335029602,disc loss=1.211248517036438, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 151, gen loss=1.0752458572387695,disc loss=1.2104729413986206, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 152, gen loss=1.0808837413787842,disc loss=1.2143049240112305, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 153, gen loss=1.0584467649459839,disc loss=1.2160630226135254, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 154, gen loss=1.0680887699127197,disc loss=1.2100114822387695, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 155, gen loss=1.1377657651901245,disc loss=1.1895596981048584, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 156, gen loss=1.071840524673462,disc loss=1.2140154838562012, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 157, gen loss=1.0699409246444702,disc loss=1.214008092880249, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 158, gen loss=1.1728178262710571,disc loss=1.187198281288147, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 159, gen loss=1.1508464813232422,disc loss=1.183293104171753, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 160, gen loss=1.1028980016708374,disc loss=1.200959324836731, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 161, gen loss=1.090858817100525,disc loss=1.2040815353393555, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 162, gen loss=1.0995014905929565,disc loss=1.195611834526062, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 163, gen loss=1.1726388931274414,disc loss=1.1784207820892334, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 164, gen loss=1.1789660453796387,disc loss=1.1735422611236572, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 165, gen loss=1.0762494802474976,disc loss=1.201453447341919, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 166, gen loss=1.1981066465377808,disc loss=1.1665455102920532, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 167, gen loss=1.171600341796875,disc loss=1.173169732093811, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 168, gen loss=1.1274120807647705,disc loss=1.1859992742538452, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 169, gen loss=1.1029053926467896,disc loss=1.1884653568267822, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 170, gen loss=1.1608664989471436,disc loss=1.1778674125671387, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 171, gen loss=1.0651137828826904,disc loss=1.2128084897994995, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 172, gen loss=1.1157604455947876,disc loss=1.1995925903320312, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 173, gen loss=1.0627630949020386,disc loss=1.201595425605774, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 174, gen loss=1.1782889366149902,disc loss=1.1687231063842773, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 175, gen loss=1.1553467512130737,disc loss=1.1741913557052612, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 176, gen loss=1.1346770524978638,disc loss=1.1844432353973389, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 177, gen loss=1.1628835201263428,disc loss=1.1716192960739136, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 178, gen loss=1.1294682025909424,disc loss=1.1786516904830933, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 179, gen loss=1.1702756881713867,disc loss=1.1739245653152466, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 180, gen loss=1.1050982475280762,disc loss=1.1968941688537598, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 181, gen loss=1.158600091934204,disc loss=1.1781764030456543, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 182, gen loss=1.3693854808807373,disc loss=1.121112585067749, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 183, gen loss=1.170148491859436,disc loss=1.1664971113204956, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 184, gen loss=1.0897495746612549,disc loss=1.1909306049346924, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 185, gen loss=1.2408266067504883,disc loss=1.1557031869888306, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 186, gen loss=1.159342885017395,disc loss=1.167352557182312, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 187, gen loss=1.150480031967163,disc loss=1.1697676181793213, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 188, gen loss=1.1530827283859253,disc loss=1.1713165044784546, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 189, gen loss=1.2260923385620117,disc loss=1.1500298976898193, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 190, gen loss=1.1871370077133179,disc loss=1.1614609956741333, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 191, gen loss=1.2080522775650024,disc loss=1.1443922519683838, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 192, gen loss=1.1635605096817017,disc loss=1.1609559059143066, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 193, gen loss=1.194189429283142,disc loss=1.1629093885421753, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 194, gen loss=1.1919397115707397,disc loss=1.1522526741027832, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 195, gen loss=1.1676760911941528,disc loss=1.1662348508834839, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 196, gen loss=1.123152256011963,disc loss=1.1839011907577515, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 197, gen loss=1.1358627080917358,disc loss=1.166603922843933, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 198, gen loss=1.2141963243484497,disc loss=1.1598988771438599, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 199, gen loss=1.2760038375854492,disc loss=1.1362204551696777, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 200, gen loss=1.2080219984054565,disc loss=1.1571866273880005, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 201, gen loss=1.2307485342025757,disc loss=1.1524512767791748, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 202, gen loss=1.2249491214752197,disc loss=1.1481045484542847, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 203, gen loss=1.2633601427078247,disc loss=1.1276984214782715, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 204, gen loss=1.2414621114730835,disc loss=1.1404629945755005, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 205, gen loss=1.2269290685653687,disc loss=1.1485570669174194, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 206, gen loss=1.2090516090393066,disc loss=1.1550226211547852, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 207, gen loss=1.2669053077697754,disc loss=1.1339902877807617, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 208, gen loss=1.4518887996673584,disc loss=1.0928138494491577, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 209, gen loss=1.4997485876083374,disc loss=1.0777649879455566, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 210, gen loss=1.4754040241241455,disc loss=1.0893378257751465, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 211, gen loss=1.3526862859725952,disc loss=1.112987756729126, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 212, gen loss=1.3496205806732178,disc loss=1.1164239645004272, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 213, gen loss=1.4036266803741455,disc loss=1.1000789403915405, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 214, gen loss=1.3089478015899658,disc loss=1.1173795461654663, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 215, gen loss=1.3565891981124878,disc loss=1.112112283706665, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 216, gen loss=1.2766696214675903,disc loss=1.124959945678711, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 217, gen loss=1.344950795173645,disc loss=1.1070359945297241, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 218, gen loss=1.4619752168655396,disc loss=1.0909456014633179, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 219, gen loss=1.4050098657608032,disc loss=1.1037967205047607, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 220, gen loss=1.3293278217315674,disc loss=1.1136289834976196, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 221, gen loss=1.3756376504898071,disc loss=1.0946974754333496, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 222, gen loss=1.3567804098129272,disc loss=1.1019362211227417, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 223, gen loss=1.3271591663360596,disc loss=1.1012134552001953, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 224, gen loss=1.5613960027694702,disc loss=1.0653364658355713, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 225, gen loss=1.6010819673538208,disc loss=1.064317226409912, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 226, gen loss=1.4795669317245483,disc loss=1.0810738801956177, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 227, gen loss=1.374590516090393,disc loss=1.1032992601394653, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 228, gen loss=1.3208847045898438,disc loss=1.1153775453567505, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 229, gen loss=1.3451249599456787,disc loss=1.108306646347046, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 230, gen loss=1.3580305576324463,disc loss=1.1023985147476196, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 231, gen loss=1.3813527822494507,disc loss=1.0916433334350586, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 232, gen loss=1.4390819072723389,disc loss=1.0915907621383667, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 233, gen loss=1.3954722881317139,disc loss=1.098629355430603, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 234, gen loss=1.3210467100143433,disc loss=1.1083481311798096, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 235, gen loss=1.3030822277069092,disc loss=1.1198841333389282, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 236, gen loss=1.3089005947113037,disc loss=1.107607364654541, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 237, gen loss=1.3339205980300903,disc loss=1.0969040393829346, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 238, gen loss=1.3553565740585327,disc loss=1.1084128618240356, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 239, gen loss=1.2749191522598267,disc loss=1.111611247062683, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 240, gen loss=1.2740223407745361,disc loss=1.1164485216140747, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 241, gen loss=1.236538290977478,disc loss=1.1246256828308105, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 242, gen loss=1.3657665252685547,disc loss=1.107930064201355, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 243, gen loss=1.373610019683838,disc loss=1.1073564291000366, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 244, gen loss=1.3383290767669678,disc loss=1.0977599620819092, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 245, gen loss=1.349438190460205,disc loss=1.0953173637390137, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 246, gen loss=1.3204556703567505,disc loss=1.0951688289642334, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 247, gen loss=1.388917088508606,disc loss=1.0859073400497437, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 248, gen loss=1.3820841312408447,disc loss=1.088417649269104, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 249, gen loss=1.3454725742340088,disc loss=1.0968347787857056, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 250, gen loss=1.3643029928207397,disc loss=1.108394980430603, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 251, gen loss=1.315882682800293,disc loss=1.098685622215271, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 252, gen loss=1.42079758644104,disc loss=1.0854512453079224, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 253, gen loss=1.4899686574935913,disc loss=1.061155080795288, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 254, gen loss=1.4804925918579102,disc loss=1.0702601671218872, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 255, gen loss=1.3981070518493652,disc loss=1.0856817960739136, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 256, gen loss=1.4275217056274414,disc loss=1.074284553527832, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 257, gen loss=1.358882188796997,disc loss=1.0859055519104004, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 258, gen loss=1.4444096088409424,disc loss=1.075176477432251, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 259, gen loss=1.3278592824935913,disc loss=1.0856057405471802, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 260, gen loss=1.3577576875686646,disc loss=1.0832629203796387, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 261, gen loss=1.4259581565856934,disc loss=1.080898404121399, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 262, gen loss=1.3857066631317139,disc loss=1.0955160856246948, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 263, gen loss=1.2999807596206665,disc loss=1.1024106740951538, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 264, gen loss=1.4022685289382935,disc loss=1.0826311111450195, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 265, gen loss=1.4564690589904785,disc loss=1.0664478540420532, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 266, gen loss=1.4206198453903198,disc loss=1.0852835178375244, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 267, gen loss=1.3885149955749512,disc loss=1.078675389289856, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 268, gen loss=1.3818362951278687,disc loss=1.090595006942749, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 269, gen loss=1.3869341611862183,disc loss=1.0880825519561768, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 270, gen loss=1.4166536331176758,disc loss=1.0737746953964233, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 271, gen loss=1.390464425086975,disc loss=1.0736664533615112, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 272, gen loss=1.4046350717544556,disc loss=1.0779308080673218, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 273, gen loss=1.4412354230880737,disc loss=1.0680294036865234, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 274, gen loss=1.4126535654067993,disc loss=1.0642019510269165, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 275, gen loss=1.3865609169006348,disc loss=1.0817766189575195, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 276, gen loss=1.4534759521484375,disc loss=1.0765854120254517, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 277, gen loss=1.4029887914657593,disc loss=1.0757228136062622, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 278, gen loss=1.415919542312622,disc loss=1.0742813348770142, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 279, gen loss=1.4482001066207886,disc loss=1.076252818107605, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 280, gen loss=1.4457683563232422,disc loss=1.0701740980148315, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 281, gen loss=1.375883936882019,disc loss=1.0844680070877075, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 282, gen loss=1.4352095127105713,disc loss=1.0703442096710205, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 283, gen loss=1.481097936630249,disc loss=1.045857310295105, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 284, gen loss=1.4450167417526245,disc loss=1.0699268579483032, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 285, gen loss=1.4125665426254272,disc loss=1.0767135620117188, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 286, gen loss=1.390845537185669,disc loss=1.0857517719268799, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 287, gen loss=1.4169062376022339,disc loss=1.0772333145141602, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 288, gen loss=1.4360350370407104,disc loss=1.0685477256774902, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 289, gen loss=1.5155937671661377,disc loss=1.0686308145523071, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 290, gen loss=1.2953799962997437,disc loss=1.106527328491211, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 291, gen loss=1.3434879779815674,disc loss=1.0847277641296387, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 292, gen loss=1.4338246583938599,disc loss=1.0710701942443848, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 293, gen loss=1.3574888706207275,disc loss=1.0884019136428833, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 294, gen loss=1.4976563453674316,disc loss=1.0625131130218506, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 295, gen loss=1.4903284311294556,disc loss=1.0476566553115845, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 296, gen loss=1.5182225704193115,disc loss=1.0490442514419556, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 297, gen loss=1.4493504762649536,disc loss=1.0687470436096191, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 298, gen loss=1.4247870445251465,disc loss=1.0636526346206665, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 299, gen loss=1.4734920263290405,disc loss=1.048081636428833, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 300, gen loss=1.3535183668136597,disc loss=1.0877426862716675, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 301, gen loss=1.3688069581985474,disc loss=1.0891445875167847, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 302, gen loss=1.406334400177002,disc loss=1.0779577493667603, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 303, gen loss=1.4149659872055054,disc loss=1.065189003944397, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 304, gen loss=1.4620054960250854,disc loss=1.0625982284545898, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 305, gen loss=1.4310768842697144,disc loss=1.0671663284301758, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 306, gen loss=1.4661504030227661,disc loss=1.0597167015075684, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 307, gen loss=1.3668984174728394,disc loss=1.0828099250793457, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 308, gen loss=1.4627161026000977,disc loss=1.0520232915878296, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 309, gen loss=1.398579478263855,disc loss=1.0596082210540771, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 310, gen loss=1.3484646081924438,disc loss=1.0888458490371704, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 311, gen loss=1.3974487781524658,disc loss=1.0747911930084229, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 312, gen loss=1.3823981285095215,disc loss=1.0782150030136108, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 313, gen loss=1.4326051473617554,disc loss=1.0683022737503052, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 314, gen loss=1.4055726528167725,disc loss=1.069372534751892, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 315, gen loss=1.43813955783844,disc loss=1.0505340099334717, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 316, gen loss=1.4112658500671387,disc loss=1.0633883476257324, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 317, gen loss=1.4869202375411987,disc loss=1.0533912181854248, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 318, gen loss=1.6118000745773315,disc loss=1.0406817197799683, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 319, gen loss=1.467922568321228,disc loss=1.0599249601364136, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 320, gen loss=1.5108672380447388,disc loss=1.0533382892608643, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 321, gen loss=1.36526358127594,disc loss=1.0726704597473145, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 322, gen loss=1.3669860363006592,disc loss=1.0791722536087036, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 323, gen loss=1.4288957118988037,disc loss=1.070275068283081, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 324, gen loss=1.4324324131011963,disc loss=1.0556960105895996, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 325, gen loss=1.371464729309082,disc loss=1.0751962661743164, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 326, gen loss=1.4124979972839355,disc loss=1.0639344453811646, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 327, gen loss=1.4224231243133545,disc loss=1.0612058639526367, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 328, gen loss=1.3970664739608765,disc loss=1.0684839487075806, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 329, gen loss=1.4312158823013306,disc loss=1.0672144889831543, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 330, gen loss=1.4318571090698242,disc loss=1.0487908124923706, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 331, gen loss=1.4917209148406982,disc loss=1.0526891946792603, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 332, gen loss=1.4557855129241943,disc loss=1.0548382997512817, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 333, gen loss=1.4702377319335938,disc loss=1.0365689992904663, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 334, gen loss=1.5014541149139404,disc loss=1.0531256198883057, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 335, gen loss=1.437162160873413,disc loss=1.056706190109253, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 336, gen loss=1.4111381769180298,disc loss=1.0614936351776123, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 337, gen loss=1.5092220306396484,disc loss=1.0437512397766113, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 338, gen loss=1.4494374990463257,disc loss=1.0495041608810425, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 339, gen loss=1.378848910331726,disc loss=1.073400616645813, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 340, gen loss=1.429166555404663,disc loss=1.063214659690857, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 341, gen loss=1.4243152141571045,disc loss=1.0569946765899658, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 342, gen loss=1.4080591201782227,disc loss=1.0677618980407715, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 343, gen loss=1.3802196979522705,disc loss=1.0758068561553955, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 344, gen loss=1.3670834302902222,disc loss=1.063706636428833, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 345, gen loss=1.3717055320739746,disc loss=1.0712521076202393, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 346, gen loss=1.4037803411483765,disc loss=1.0658751726150513, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 347, gen loss=1.3786771297454834,disc loss=1.0666264295578003, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 348, gen loss=1.3974754810333252,disc loss=1.057919979095459, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 349, gen loss=1.3943876028060913,disc loss=1.055321455001831, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 350, gen loss=1.4771380424499512,disc loss=1.0601320266723633, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 351, gen loss=1.452035665512085,disc loss=1.051995038986206, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 352, gen loss=1.5650674104690552,disc loss=1.035109281539917, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 353, gen loss=1.452846884727478,disc loss=1.0472768545150757, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 354, gen loss=1.407056212425232,disc loss=1.0657762289047241, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 355, gen loss=1.3486965894699097,disc loss=1.0700223445892334, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 356, gen loss=1.4044617414474487,disc loss=1.05415678024292, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 357, gen loss=1.4457244873046875,disc loss=1.0474636554718018, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 358, gen loss=1.4753376245498657,disc loss=1.0412752628326416, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 359, gen loss=1.4595074653625488,disc loss=1.0407884120941162, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 360, gen loss=1.4808670282363892,disc loss=1.0252511501312256, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 361, gen loss=1.5446879863739014,disc loss=1.028285026550293, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 362, gen loss=1.497193455696106,disc loss=1.0512973070144653, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 363, gen loss=1.5301414728164673,disc loss=1.0408233404159546, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 364, gen loss=1.5348401069641113,disc loss=1.0324681997299194, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 365, gen loss=1.5204013586044312,disc loss=1.0356615781784058, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 366, gen loss=1.4107917547225952,disc loss=1.0548062324523926, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 367, gen loss=1.442828893661499,disc loss=1.0448085069656372, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 368, gen loss=1.5326426029205322,disc loss=1.0325000286102295, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 369, gen loss=1.4420747756958008,disc loss=1.054799199104309, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 370, gen loss=1.5328530073165894,disc loss=1.0282621383666992, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 371, gen loss=1.5460728406906128,disc loss=1.0253782272338867, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 372, gen loss=1.5195132493972778,disc loss=1.0390782356262207, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 373, gen loss=1.4685472249984741,disc loss=1.0424708127975464, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 374, gen loss=1.457208275794983,disc loss=1.0341614484786987, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 375, gen loss=1.6400479078292847,disc loss=1.0112347602844238, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 376, gen loss=1.4842499494552612,disc loss=1.0323798656463623, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 377, gen loss=1.453442931175232,disc loss=1.048325777053833, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 378, gen loss=1.4581153392791748,disc loss=1.0417739152908325, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 379, gen loss=1.4603511095046997,disc loss=1.0503172874450684, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 380, gen loss=1.4473850727081299,disc loss=1.03761887550354, 0:00:13.93
# model saved
# epoch start...
# now
# Epoch 381, gen loss=1.4360191822052002,disc loss=1.0485010147094727, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 382, gen loss=1.4193867444992065,disc loss=1.059273362159729, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 383, gen loss=1.3963005542755127,disc loss=1.0598832368850708, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 384, gen loss=1.4867511987686157,disc loss=1.030622959136963, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 385, gen loss=1.5801105499267578,disc loss=1.0142605304718018, 0:00:13.93
# model saved
# epoch start...
# now
# Epoch 386, gen loss=1.6065919399261475,disc loss=1.0105072259902954, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 387, gen loss=1.5589418411254883,disc loss=1.0137909650802612, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 388, gen loss=1.5936598777770996,disc loss=1.007201075553894, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 389, gen loss=1.5642566680908203,disc loss=1.0144016742706299, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 390, gen loss=1.5264006853103638,disc loss=1.0249552726745605, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 391, gen loss=1.4942024946212769,disc loss=1.0385985374450684, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 392, gen loss=1.5116698741912842,disc loss=1.0244648456573486, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 393, gen loss=1.4970052242279053,disc loss=1.0395625829696655, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 394, gen loss=1.5188846588134766,disc loss=1.0295863151550293, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 395, gen loss=1.576945424079895,disc loss=1.0115408897399902, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 396, gen loss=1.493349313735962,disc loss=1.0241451263427734, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 397, gen loss=1.4588191509246826,disc loss=1.0396500825881958, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 398, gen loss=1.4771071672439575,disc loss=1.0253491401672363, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 399, gen loss=1.6346721649169922,disc loss=1.011216640472412, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 400, gen loss=1.5002777576446533,disc loss=1.0397266149520874, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 401, gen loss=1.5518075227737427,disc loss=1.0126194953918457, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 402, gen loss=1.5676645040512085,disc loss=1.0198630094528198, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 403, gen loss=1.5432541370391846,disc loss=1.0245072841644287, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 404, gen loss=1.442264437675476,disc loss=1.040435791015625, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 405, gen loss=1.529737949371338,disc loss=1.0316898822784424, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 406, gen loss=1.4723830223083496,disc loss=1.028192400932312, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 407, gen loss=1.52437162399292,disc loss=1.0278886556625366, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 408, gen loss=1.5475924015045166,disc loss=1.0117770433425903, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 409, gen loss=1.574514627456665,disc loss=1.0166209936141968, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 410, gen loss=1.5474319458007812,disc loss=1.018890619277954, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 411, gen loss=1.5941648483276367,disc loss=1.008239507675171, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 412, gen loss=1.5128564834594727,disc loss=1.0147782564163208, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 413, gen loss=1.5832715034484863,disc loss=1.0042188167572021, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 414, gen loss=1.491452932357788,disc loss=1.030686855316162, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 415, gen loss=1.5302952527999878,disc loss=1.015711784362793, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 416, gen loss=1.6135042905807495,disc loss=1.0204459428787231, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 417, gen loss=1.5491914749145508,disc loss=1.0040956735610962, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 418, gen loss=1.482361912727356,disc loss=1.0221452713012695, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 419, gen loss=1.5082180500030518,disc loss=1.0170269012451172, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 420, gen loss=1.5950123071670532,disc loss=1.0072849988937378, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 421, gen loss=1.492327094078064,disc loss=1.0170034170150757, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 422, gen loss=1.5895400047302246,disc loss=1.0058965682983398, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 423, gen loss=1.5422934293746948,disc loss=1.0202373266220093, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 424, gen loss=1.5767464637756348,disc loss=1.0099759101867676, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 425, gen loss=1.6874045133590698,disc loss=1.0004130601882935, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 426, gen loss=1.5295697450637817,disc loss=1.014597773551941, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 427, gen loss=1.5376861095428467,disc loss=1.0074827671051025, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 428, gen loss=1.4952971935272217,disc loss=1.0254334211349487, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 429, gen loss=1.5492066144943237,disc loss=1.021796703338623, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 430, gen loss=1.5359331369400024,disc loss=1.0211737155914307, 0:00:13.93
# model saved
# epoch start...
# now
# Epoch 431, gen loss=1.536233901977539,disc loss=1.017643928527832, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 432, gen loss=1.6403095722198486,disc loss=0.9971216917037964, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 433, gen loss=1.6085529327392578,disc loss=1.0034840106964111, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 434, gen loss=1.5110249519348145,disc loss=1.025363802909851, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 435, gen loss=1.6092849969863892,disc loss=1.0150283575057983, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 436, gen loss=1.5604826211929321,disc loss=1.0128023624420166, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 437, gen loss=1.5636612176895142,disc loss=1.010718822479248, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 438, gen loss=1.6397544145584106,disc loss=0.9855116605758667, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 439, gen loss=1.5670002698898315,disc loss=1.0029733180999756, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 440, gen loss=1.509442687034607,disc loss=1.0232503414154053, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 441, gen loss=1.4781970977783203,disc loss=1.0177940130233765, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 442, gen loss=1.5734176635742188,disc loss=1.0168132781982422, 0:00:13.93
# model saved
# epoch start...
# now
# Epoch 443, gen loss=1.491272211074829,disc loss=1.0176419019699097, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 444, gen loss=1.5388946533203125,disc loss=1.0193967819213867, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 445, gen loss=1.545560359954834,disc loss=1.0095996856689453, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 446, gen loss=1.561415672302246,disc loss=1.0142656564712524, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 447, gen loss=1.6068819761276245,disc loss=0.9988262057304382, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 448, gen loss=1.584189772605896,disc loss=1.0006067752838135, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 449, gen loss=1.5943480730056763,disc loss=1.0049664974212646, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 450, gen loss=1.5758851766586304,disc loss=0.9966365694999695, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 451, gen loss=1.5417536497116089,disc loss=1.0073697566986084, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 452, gen loss=1.6709715127944946,disc loss=0.9856752753257751, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 453, gen loss=1.676064372062683,disc loss=0.9691770672798157, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 454, gen loss=1.697304606437683,disc loss=0.9801377058029175, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 455, gen loss=1.633666753768921,disc loss=0.9955212473869324, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 456, gen loss=1.5950415134429932,disc loss=0.9933748245239258, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 457, gen loss=1.6773806810379028,disc loss=0.9948926568031311, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 458, gen loss=1.5723538398742676,disc loss=1.0061894655227661, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 459, gen loss=1.690396785736084,disc loss=0.9842513799667358, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 460, gen loss=1.605613112449646,disc loss=0.9974315762519836, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 461, gen loss=1.6597325801849365,disc loss=0.9833067059516907, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 462, gen loss=1.5643415451049805,disc loss=0.9973998665809631, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 463, gen loss=1.5746328830718994,disc loss=0.9903209209442139, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 464, gen loss=1.5884298086166382,disc loss=1.0086073875427246, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 465, gen loss=1.5279146432876587,disc loss=1.0121657848358154, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 466, gen loss=1.5954078435897827,disc loss=1.0031490325927734, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 467, gen loss=1.5328354835510254,disc loss=1.0014437437057495, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 468, gen loss=1.5390784740447998,disc loss=1.0070106983184814, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 469, gen loss=1.5795403718948364,disc loss=1.0050491094589233, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 470, gen loss=1.654421091079712,disc loss=0.9916347861289978, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 471, gen loss=1.7253265380859375,disc loss=0.985824704170227, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 472, gen loss=1.7205803394317627,disc loss=0.9747075438499451, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 473, gen loss=1.656477451324463,disc loss=0.987862765789032, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 474, gen loss=1.7472283840179443,disc loss=0.978534996509552, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 475, gen loss=1.6346945762634277,disc loss=0.9814823269844055, 0:00:13.90
# model saved
# epoch start...
# now
# Epoch 476, gen loss=1.6145833730697632,disc loss=0.996040403842926, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 477, gen loss=1.727513313293457,disc loss=0.9863397479057312, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 478, gen loss=1.6516435146331787,disc loss=0.9854393005371094, 0:00:13.92
# model saved
# epoch start...
# now
# Epoch 479, gen loss=1.6496906280517578,disc loss=0.991023600101471, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 480, gen loss=1.622343897819519,disc loss=0.9858050346374512, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 481, gen loss=1.6093716621398926,disc loss=0.992753267288208, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 482, gen loss=1.5888155698776245,disc loss=0.9898584485054016, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 483, gen loss=1.6945940256118774,disc loss=0.980182409286499, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 484, gen loss=1.583742618560791,disc loss=0.985983669757843, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 485, gen loss=1.5687490701675415,disc loss=1.0010030269622803, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 486, gen loss=1.6252564191818237,disc loss=0.9861857891082764, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 487, gen loss=1.615488886833191,disc loss=0.9844526052474976, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 488, gen loss=1.643958568572998,disc loss=0.9826723337173462, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 489, gen loss=1.7019333839416504,disc loss=0.9815001487731934, 0:00:13.91
# model saved
# epoch start...
# now
# Epoch 490, gen loss=1.7430413961410522,disc loss=0.9662695527076721, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 491, gen loss=1.7011505365371704,disc loss=0.973661482334137, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 492, gen loss=1.65424644947052,disc loss=0.9797667860984802, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 493, gen loss=1.6927658319473267,disc loss=0.9787740111351013, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 494, gen loss=1.6480730772018433,disc loss=0.9711151719093323, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 495, gen loss=1.6879737377166748,disc loss=0.9746974110603333, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 496, gen loss=1.6189032793045044,disc loss=0.9792947769165039, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 497, gen loss=1.663230538368225,disc loss=0.9770312905311584, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 498, gen loss=1.735973834991455,disc loss=0.9738437533378601, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 499, gen loss=1.6404070854187012,disc loss=0.9853034019470215, 0:00:13.89
# model saved
# epoch start...
# now
# Epoch 500, gen loss=1.751351237297058,disc loss=0.9531461000442505, 0:00:13.90
# model saved
# Training time: 2:16:22.63

# %% [markdown]
# ## Results

# %%
save_images_embeddings.shape
# Out:
# (28, 300)

# %%
# Printing the captions
save_images_captions
# Out:
# ['prominent purple stigma , petals are white inc olor',
#  'this flower is blue and green in color ,  with petals that are oval shaped . ',
#  'outer petals are green in color and klarger , inner petals are needle shaped',
#  'there are several shapes ,  sizes ,  and colors of petals on this complex flower . ',
#  'the stamen are towering over the stigma which cannot be seen . ',
#  'this flower is white and purple in color ,  with petals that are oval shaped . ',
#  'the petals of this flower are green with a long stigma',
#  'the blossom has a layer of rounded purple and white petals topped by a layer of fringed purple petals . ',
#  'this flower is purple and yellow in color ,  with petals that are oval shaped . ',
#  'the petals on this flower are white with an elaborate pistil . ',
#  'this flower has petals that are pink with stringy white stamen',
#  'this flower has star shaped white petals as its main feature . ',
#  'lower petals are white in color , and larger in size , inner petals are purple in clor',
#  'this flower has petals in the shape of a circle and are purple and stringy',
#  'a unique looking flower that has multiple colors and long petals',
#  'this flower is white and purple in color ,  with petals that are oval shaped . ',
#  'this flower is white in color ,  with petals that are oval shaped . ',
#  'this flower has thick star shaped maroon petals as its main feature . ',
#  'this flower has petals that are white with purple stringy stamen',
#  'the pistil is white and is very noticeable ,  and the petals are purple . ',
#  'purple flower with curvy string - like petals and a group of large yellow stamen in the center . ',
#  'this flower has an elaborate golden stamen and two different types of purple petals . ',
#  'flower with white long white petals and very long purple stamen',
#  'this flower is blue and white in color ,  with petals that are oval shaped . ',
#  'leaves are green in color , outer petals are white green in color',
#  'the petals of the flower are pink in color and have filaments that are pink in color . ',
#  'this is a purple flower with long purple anthers on it . ',
#  'this is a strange flower with purple petals and a white stigma . ']

# %%
def test_image(text,num):
  test_embeddings = np.zeros((1,300),dtype=np.float32)

  x = text.lower()
  x = x.replace(" ","")
  count = 0
  for t in x:
    try:
      test_embeddings[0] += glove_embeddings[t]
      count += 1
    except:
      print(t)
      pass
  test_embeddings[0] /= count
  test_embeddings =  np.repeat(test_embeddings,[28],axis=0)
  noise = tf.random.normal([28, 100])
  save_images(num,noise,test_embeddings)

# %%
test_image("this flower is purple in color with oval shaped petals",1)

# %%
import IPython
IPython.display.Image('/content/drive/Shareddrives/D4NLP Project/flowers data/flowers/output_64_character_extended/train-1.png')

# %%
test_image("this flower is yellow in color with oval shaped petals",2)

# %%
import IPython
IPython.display.Image('/content/drive/Shareddrives/D4NLP Project/flowers data/flowers/output_64_character_extended/train-2.png')

# %%
test_image("this flower is pink in color with oval shaped petals",3)

# %%
import IPython
IPython.display.Image('/content/drive/Shareddrives/D4NLP Project/flowers data/flowers/output_64_character_extended/train-3.png')

# %% [markdown]
# Code Reference:
# https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_07_2_Keras_gan.ipynb
#
# Paper Reference:
# https://arxiv.org/pdf/1605.05396.pdf
